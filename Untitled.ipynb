# %%
import matplotlib.pyplot as plt
import nibabel as nib
import os

# %%
path = "PKG - BraTS-Africa/BraTS-Africa/95_Glioma/BraTS-SSA-00230-000"

# %%
for img in os.listdir(path):
    img_path = os.path.join(path, img)
    image = nib.load(img_path)
    a = image.get_fdata()
    print(a.shape)
    print(path)
    plt.imshow(a[:,:,77], cmap="grey")
    plt.show()
# Out:
# (240, 240, 155)
# PKG - BraTS-Africa/BraTS-Africa/95_Glioma/BraTS-SSA-00230-000
# (240, 240, 155)
# PKG - BraTS-Africa/BraTS-Africa/95_Glioma/BraTS-SSA-00230-000
# (240, 240, 155)
# PKG - BraTS-Africa/BraTS-Africa/95_Glioma/BraTS-SSA-00230-000
# (240, 240, 155)
# PKG - BraTS-Africa/BraTS-Africa/95_Glioma/BraTS-SSA-00230-000
# ---------------------------------------------------------------------------
# ImageFileError                            Traceback (most recent call last)
# Cell In[50], line 3
#       1 for img in os.listdir(path):
#       2     img_path = os.path.join(path, img)
# ----> 3     image = nib.load(img_path)
#       4     a = image.get_fdata()
#       5     print(a.shape)
#
# File ~\miniconda3\envs\ml\lib\site-packages\nibabel\loadsave.py:104, in load(filename, **kwargs)
#     102     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     103 if stat_result.st_size <= 0:
# --> 104     raise ImageFileError(f"Empty file: '{filename}'")
#     106 sniff = None
#     107 for image_klass in all_image_classes:
#
# ImageFileError: Empty file: 'PKG - BraTS-Africa/BraTS-Africa/95_Glioma/BraTS-SSA-00230-000/BraTS-SSA-00230-000-t2w.nii.gz'

# %%
img = nib.load(pat)

# %%
a = img.get_fdata()

# %%
a.shape
# Out:
# (240, 240, 155)

# %%
plt.imshow(a[:,:,76])
